# %% [raw]
# Ques 1.) What exactly is [] ?
#
# Solution :
#
# In Python, square brackets, [ ], are primarily used for creating and accessing lists, which are a fundamental
# data structure in the language. Here are some common use cases:
#
# 1.) List creation : Square brackets are used to define a list literal. For example, my_list = [1, 2, 3] creates a
# list called my_list with three elements: 1, 2, and 3.
#
# 2.) List indexing : Square brackets are used to access individual elements within a list. The index inside the brackets
# specifies the position of the element in the list. In Python, list indices start from 0. For example, my_list[0]
# would retrieve the first element of the list my_list.
#
# 3.) List slicing : Square brackets can also be used to extract a sublist, or a portion of a list, using slicing. The
# slice notation consists of two indices separated by a colon inside the square brackets. For example, my_list[1:3]
# would retrieve a new list containing elements from index 1 up to, but not including, index 3.
#
# 4.) List modification : Square brackets are used to modify individual elements within a list. By assigning a new value
# to a specific index using the square bracket notation, you can change the element's value. For example,
# my_list[0] = 4 would change the first element of my_list to 4.
#
# It's important to note that square brackets can be used in other contexts as well, such as to create dictionaries
# or to represent indexing and slicing in other data structures like strings or arrays. However, in Python, square
# brackets are primarily associated with list-related operations.

# %% [raw]
# Ques 2.) In a list of values stored in a variable called spam, how would you assign the value 'hello' as the
# third value ? (Assume [2, 4, 6, 8, 10] are in spam.)
#
# Solution :
#
# To assign the value 'hello' as the third value in a list stored in the variable spam, we can use the index notation
# and assign the value directly. Here's how we can do it :
#
# spam = [2, 4, 6, 8, 10]  # Original list
# spam[2] = 'hello'  # Assign 'hello' as the third value
#
# In the above code, spam[2] refers to the third element of the list spam (remember that indexing starts from 0).
# By assigning the value 'hello' to spam[2], replacing the existing value at that position with 'hello'. After executing
# this code, the list spam will be updated as [2, 4, 'hello', 8, 10].

# %% [raw]
# Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.
#
# Ques 3.) What is the value of spam[int(int('3'* 2) / 11)] ?
# Ques 4.) What is the value of spam[-1] ?
# Ques 5.) What is the value of spam[:2] ?
#
# Solution :
#
# Let's evaluate each of the queries :
#
# 3.) The expression '3' * 2 results in the string '33'. Then, int('33') is converted to an integer value of 33. Dividing 33 by
#     11 gives us 3. The index operator spam[3] retrieves the value at index 3 in the list, which is 'd'.
#
#     Therefore, the value of spam[int(int('3'* 2) / 11)] is 'd'.
#
# 4.) The index -1 in Python represents the last element of a list. In this case, spam[-1] will retrieve the last element of the
#     list ['a', 'b', 'c', 'd'], which is 'd'.
#
#     Therefore, the value of spam[-1] is 'd'.
#
# 5.) The slicing notation spam[:2] retrieves a sublist from the beginning of the list up to, but not including, the element at
#     index 2. In this case, it will retrieve the elements at index 0 and index 1, which are 'a' and 'b' respectively.
#
#     Therefore, the value of spam[:2] is ['a', 'b'].

# %% [raw]
# Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.
#
# Ques 6.) What is the value of bacon.index('cat') ?
# Ques 7.) How does bacon.append(99) change the look of the list value in bacon ?
# Ques 8.) How does bacon.remove('cat') change the look of the list in bacon ?
#
# Solution :
#
# Let's solve each of the questions using Python :
#
# bacon = [3.14, 'cat', 11, 'cat', True]
#
# # 6.) What is the value of bacon.index('cat') ?
#
# cat_index = bacon.index('cat')
# print(cat_index)
#
# The output will be :
#     1
# So, the value of bacon.index('cat') is 1.
#
# # 7.) How does bacon.append(99) change the look of the list value in bacon ?
#
# bacon.append(99)
# print(bacon)
#
# The output will be :
# [3.14, 'cat', 11, 'cat', True, 99]
#
# So, the list value in bacon will be changed to [3.14, 'cat', 11, 'cat', True, 99] after appending 99 to it.
#
# # 8.) How does bacon.remove('cat') change the look of the list in bacon ?
#
# bacon.remove('cat')
# print(bacon)
#
# The output will be :
# [3.14, 11, 'cat', True]
#
# So, the list in bacon will be changed to [3.14, 11, 'cat', True] after removing the first occurrence of 'cat'.

# %% [raw]
# Ques 9.) What are the list concatenation and list replication operators ?
#
# Solution :
#
# In Python, the list concatenation operator is the plus sign (+), and the list replication operator is the asterisk (*).
# Here's a brief explanation of each:
#
# 1.) List Concatenation Operator (+) :
#
# The list concatenation operator allows you to combine two or more lists into a single list. When you use the plus sign (+)
# between two lists, it creates a new list that contains all the elements from both lists, in the order they appear.
# Here's an example :
#
# list1 = [1, 2, 3]
# list2 = [4, 5, 6]
# concatenated_list = list1 + list2
# print(concatenated_list)
#
# Output :
# [1, 2, 3, 4, 5, 6]
#
# 2.) List Replication Operator () :
#
# The list replication operator allows you to create a new list by replicating the elements of an existing list a certain
# number of times. When you use the asterisk () followed by an integer and a list, it creates a new list by repeating the
# elements of the original list. Here's an example:
#
# original_list = [1, 2, 3]
# replicated_list = original_list * 3
# print(replicated_list)
#
# Output :
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
#
# In the example above, the elements of original_list [1, 2, 3] are repeated three times to create replicated_list.
#
# It's important to note that both operators (+ and *) return new lists and do not modify the original lists.

# %% [raw]
# Ques 10.) What is difference between the list methods append() and insert() ?
#
# Solution :
#
# Both append() and insert() are list methods in Python, but they differ in how they add elements to a list :
#
# 1.) append() :
#
# The append() method is used to add an element to the end of a list. It modifies the original list by adding the element
# as the last item. Here's an example :
#
# my_list = [1, 2, 3]
# my_list.append(4)
# print(my_list)
#
# Output :
# [1, 2, 3, 4]
#
# In the example above, append(4) adds the element 4 to the end of the list my_list.
#
# 2.) insert() :
#
# The insert() method is used to add an element at a specific position in a list. It modifies the original list by inserting
# the element at the specified index, shifting the existing elements to the right. Here's an example :
#
# my_list = [1, 2, 3]
# my_list.insert(1, 4)
# print(my_list)
#
# Output :
# [1, 4, 2, 3]
#
# In the example above, insert(1, 4) inserts the element 4 at index 1 in the list my_list. The existing elements are shifted
# to the right to accommodate the new element.
#
# To summarize, append() adds an element to the end of the list, while insert() allows you to add an element at a specific
# position within the list.

# %% [raw]
# Ques 11.) What are the two methods for removing items from a list ?
#
# Solution :
#
# There are two commonly used methods for removing items from a list in Python:
#
# 1.) remove() method :
#
# The remove() method is used to remove the first occurrence of a specified element from a list. It modifies the original
# list by finding the first occurrence of the element and removing it. Here's an example :
#
# my_list = [1, 2, 3, 4, 2]
# my_list.remove(2)
# print(my_list)
#
# Output :
# [1, 3, 4, 2]
#
# In the example above, remove(2) removes the first occurrence of the element 2 from the list my_list.
#
# 2.) pop() method :
#
# The pop() method is used to remove an element at a specific index from a list and return its value. It modifies the original
# list by removing the element at the specified index. Here's an example :
#
# my_list = [1, 2, 3, 4]
# popped_element = my_list.pop(2)
# print(popped_element)
# print(my_list)
#
# Output :
# [1, 2, 4]
#
# In the example above, pop(2) removes the element at index 2 (which is 3) from the list my_list and returns its value.
# The list is modified, and the returned value is stored in the variable popped_element.
#
# It's important to note that remove() removes the first occurrence of a specified element, while pop() removes an element
# at a specified index and returns its value. Both methods modify the original list.

# %% [raw]
# Ques 12.) Describe how list values and string values are identical.
#
# Solution :
#
# List values and string values in Python have some similarities, but they are fundamentally different data types. Here are
# a few ways in which list values and string values can be considered similar:
#
# 1.) Sequential Data :
#
#     Both lists and strings can be thought of as sequential data structures. Lists store a collection of items, and strings
#     store a sequence of characters. They both maintain the order of the elements or characters they contain.
#
# 2.) Indexing and Slicing :
#
#     Both lists and strings support indexing and slicing operations. we can access individual elements or characters by
#     their index, and we can retrieve sublists or substrings by specifying a range of indices.
#
# 3.) Immutable vs. Mutable :
#
#     Strings in Python are immutable, meaning their individual characters cannot be changed once they are assigned.
#     Similarly, individual elements in a tuple (another sequence type in Python) cannot be modified. In contrast, lists are
#     mutable, allowing us to modify, add, or remove elements after they are created.
#
# 3.) Iteration :
#
#     Both lists and strings can be iterated over using loops or other iterable processing constructs in Python. we can
#     iterate over the elements of a list or the characters of a string and perform operations on them.
#
# 4.) Length :
#
#     We can determine the length of a list or a string using the len() function. It returns the number of elements in a list
#     or the number of characters in a string.
#
# Despite these similarities, it's important to note that lists and strings serve different purposes and have different
# behaviors. Lists are used to store collections of items, while strings are used to represent textual data. Understanding
# their differences is crucial for effectively working with each data type in Python.

# %% [raw]
# Ques 13.) What is the difference between tuples and lists ?
#
# Solution :
#
# Tuples and lists are both used to store collections of items in Python, but they have several differences in terms of their
# characteristics and usage:
#
# 1.) Mutability :
#
# Lists are mutable, meaning their elements can be modified, added, or removed after the list is created. Tuples, on the other
# hand, are immutable, meaning their elements cannot be changed once they are assigned. If we need a data structure that is
# immutable and its elements should remain unchanged, tuples are a suitable choice.
#
# 2.) Syntax :
#
# Lists are defined using square brackets [], and elements are separated by commas. Tuples are defined using parentheses (),
# and elements are also separated by commas. However, it's common to define tuples without parentheses as well.
#
# 3.) Usage :
#
# Lists are commonly used when we have a collection of items that may change or require modification. They are suitable for
# scenarios where we need to add, remove, or modify elements dynamically. Tuples, on the other hand, are often used to
# represent a collection of related values that should remain unchanged. Tuples are frequently used for returning multiple
# values from a function or as keys in dictionaries.
#
# 4.) Performance :
#
# Due to their immutability, tuples are generally faster to access and iterate over compared to lists. Lists, being mutable,
# require additional overhead to support modifications. If we have a collection of values that won't change, using tuples
# can provide a performance advantage.
#
# 5.) Methods and Operations :
#
# Lists have more built-in methods and operations available compared to tuples. Since lists are mutable, they offer methods
# like append(), insert(), remove(), and more. Tuples have fewer methods and operations available because they are immutable,
# but they still support basic operations like indexing, slicing, and iterating.
#
# It's important to choose the appropriate data structure based on the specific requirements of the program. If we need a
# collection that can be modified or reordered, use a list. If we have a collection of values that should remain unchanged,
# use a tuple.

# %% [raw]
# Ques 14.) How do you type a tuple value that only contains the integer 42 ?
#
# Solution :
#
# To create a tuple value that only contains the integer 42, we can use the following syntax :
#
# my_tuple = (42,)
#
# In this example, the parentheses ( ) are used to define the tuple, and the comma , after the integer 42 is necessary to
# differentiate it from other expressions. Even though there is only one element in the tuple, the comma is still required
# to indicate that it's a tuple and not just an integer value.
#
# We can verify the type and contents of the tuple using the type() and print() functions :
#
# my_tuple = (42,)
# print(type(my_tuple))  # Output: <class 'tuple'>
# print(my_tuple)        # Output: (42,)
#
# The output confirms that my_tuple is a tuple containing the integer 42.

# %% [raw]
# Ques 15.) How do you get a list value's tuple form ? How do you get a tuple value's list form ?
#
# Solution :
#
# To convert a list to a tuple, we can use the tuple() function, and to convert a tuple to a list, we can use the list()
# function. Here's how we can achieve both conversions :
#
# 1.) Converting a list to a tuple using tuple() :
#
#     my_list = [1, 2, 3, 4]
#     my_tuple = tuple(my_list)
#     print(my_tuple)
#
# Output :
#     (1, 2, 3, 4)
#
# In the example above, the tuple() function is used to convert my_list to a tuple, resulting in (1, 2, 3, 4).
#
# 2.) Converting a tuple to a list using list() :
#
#     my_tuple = (1, 2, 3, 4)
#     my_list = list(my_tuple)
#     print(my_list)
#
# Ouput :
#     [1, 2, 3, 4]
#
# In this example, the list() function is used to convert my_tuple to a list, resulting in [1, 2, 3, 4].
#
# Both tuple() and list() functions perform the necessary conversion, allowing us to switch between the two data types
# as needed. It's important to note that when converting a list to a tuple or a tuple to a list, the order of the elements is
# maintained.

# %% [raw]
# Ques 16.) Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain ?
#
# Solution :
#
# Variables that "contain" list values in Python are not actually storing the list directly. Instead, they store a reference
# to the list object. In other words, the variable contains a memory address that points to the location of the list in the
# computer's memory.
#
# To clarify further, when we assign a list to a variable, the variable doesn't store the list elements directly. It stores
# a reference to the list, which allows us to access and manipulate the list through the variable.
#
# Here's an example to illustrate this concept :
#
# my_list = [1, 2, 3, 4]
#
# In the code above, my_list is a variable that "contains" a list value. However, it doesn't hold the actual list elements.
# Instead, it holds a reference to the list object in memory.
#
# This distinction becomes important when working with multiple variables referencing the same list. For example :
#
# list1 = [1, 2, 3]
# list2 = list1
#
# In this case, both list1 and list2 are separate variables that reference the same list object. Modifying the list through
# one variable will affect the list when accessed through the other variable :
#
# list2.append(4)
# print(list1)  # Output: [1, 2, 3, 4]
#
# As shown above, when we modify list2 by appending an element, the change is reflected when we access list1 as well. This
# is because both variables are pointing to the same underlying list object.
#
# Therefore, it's crucial to understand that variables containing list values store references to the list objects rather
# than the lists themselves.

# %% [raw]
# Ques 17.) How do you distinguish between copy.copy() and copy.deepcopy() ?
#
# Solution :
#
# The copy module in Python provides two functions, copy() and deepcopy(), for creating copies of objects. Here's how we can
# distinguish between copy.copy() and copy.deepcopy() :
#
# 1.) copy.copy() :
#
# The copy.copy() function creates a shallow copy of an object. Shallow copy means that a new object is created, but the
# contents (including nested objects) are still references to the same objects as the original. Any modifications to the
# original object's nested objects will be reflected in the copied object, and vice versa. However, the top-level objects
# themselves are independent. This method is suitable for simple objects without deeply nested structures.
#
# 2.) copy.deepcopy() :
#
# The copy.deepcopy() function creates a deep copy of an object. Deep copy means that a new object is created, and the contents
# (including nested objects) are recursively copied, resulting in completely independent objects. Modifications to the original
# object or its nested objects will not affect the copied object, and vice versa. This method is suitable for objects with
# complex or nested structures.
#
# Here's an example to illustrate the difference between copy.copy() and copy.deepcopy() :
#
# import copy
#
# # Original list with nested structure
# original_list = [1, [2, 3], [4, 5]]
#
# # Shallow copy using copy.copy()
# shallow_copy = copy.copy(original_list)
#
# # Deep copy using copy.deepcopy()
# deep_copy = copy.deepcopy(original_list)
#
# # Modifying the original list and its nested objects
# original_list[0] = 99
# original_list[1].append(4)
#
# print(original_list)   # Output: [99, [2, 3, 4], [4, 5]]
# print(shallow_copy)    # Output: [99, [2, 3, 4], [4, 5]]
# print(deep_copy)       # Output: [1, [2, 3], [4, 5]]
#
# As shown in the example, modifying the original list affects the shallow copy, as both still reference the same
# nested objects. However, the deep copy remains unaffected, as it creates independent copies of the original list and
# its nested objects.
#
# In summary, copy.copy() creates a shallow copy where the nested objects are still shared between the original and copied
# objects, while copy.deepcopy() creates a deep copy where all objects, including nested ones, are fully independent.
